# %%
# import dependencies
import pandas as pd
import sqlalchemy 
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
# read in Christmas Carols csv
df = pd.read_csv('ChristmasCarols.csv')
carol_df = pd.DataFrame(df)
carol_df.head()
# Out:
#                             Title                             Artist  Year  \
# 0  "Christmas Eve/Sarajevo 12/24"                           Savatage  1996
# 1  "Redneck 12 Days of Christmas"                     Jeff Foxworthy  1995
# 2                  "Christmas Is"  Jim Brickman featuring Mark Masri  2008
# 3                "Christmas Time"                      John Anderson  1994
# 4        "Christmas Time Is Here"                    Ray Parker, Jr.  1982
#
#                               Additional information
# 0  The song is a medley including "God Rest Ye Me...
# 1  Peaked at No. 18 on Billboard's Hot Country Si...
# 2  Peaked at No. 18 on the Billboard Hot Adult Co...
# 3  Reached No. 57 on the Billboard Hot Country Si...
# 4  Re-issued in 1984 as the B-side of Parker's to...

# %%
# clean data
# clean Title column
carol_df['Title'].str.replace(r"\"","")
# Out:
# <ipython-input-7-edfeb3a3c376>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   carol_df['Title'].str.replace(r"\"","")
# 0               Christmas Eve/Sarajevo 12/24
# 1               Redneck 12 Days of Christmas
# 2                               Christmas Is
# 3                             Christmas Time
# 4                     Christmas Time Is Here
#                        ...
# 608    Yes, Patricia, There Is a Santa Claus
# 609                             Yingle Bells
# 610            You're a Mean One, Mr. Grinch
# 611            You're a Mean One, Mr. Grinch
# 612                   'Zat You, Santa Claus?
# Name: Title, Length: 613, dtype: object

# %%
carol_df.head()
# Out:
#                             Title                             Artist  Year  \
# 0  "Christmas Eve/Sarajevo 12/24"                           Savatage  1996
# 1  "Redneck 12 Days of Christmas"                     Jeff Foxworthy  1995
# 2                  "Christmas Is"  Jim Brickman featuring Mark Masri  2008
# 3                "Christmas Time"                      John Anderson  1994
# 4        "Christmas Time Is Here"                    Ray Parker, Jr.  1982
#
#                               Additional information
# 0  The song is a medley including "God Rest Ye Me...
# 1  Peaked at No. 18 on Billboard's Hot Country Si...
# 2  Peaked at No. 18 on the Billboard Hot Adult Co...
# 3  Reached No. 57 on the Billboard Hot Country Si...
# 4  Re-issued in 1984 as the B-side of Parker's to...

# %%
# clean title column in dataframe
carol_df["Title"] =carol_df['Title'].str.replace(r"\"","")
# Out:
# <ipython-input-9-892128170bb3>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   carol_df["Title"] =carol_df['Title'].str.replace(r"\"","")

# %%
carol_df.head(10)
# Out:
#                           Title  \
# 0  Christmas Eve/Sarajevo 12/24
# 1  Redneck 12 Days of Christmas
# 2                  Christmas Is
# 3                Christmas Time
# 4        Christmas Time Is Here
# 5                 Christmastime
# 6                Happy New Year
# 7                     Mistletoe
# 8    The Night Before Christmas
# 9                This Christmas
#
#                                               Artist  Year  \
# 0                                           Savatage  1996
# 1                                     Jeff Foxworthy  1995
# 2                  Jim Brickman featuring Mark Masri  2008
# 3                                      John Anderson  1994
# 4                                    Ray Parker, Jr.  1982
# 5                              The Smashing Pumpkins  1997
# 6                                               ABBA  1980
# 7                                      Justin Bieber  2011
# 8                                        Carly Simon  1992
# ...

# %%
# clean Artist column
carol_df["Artist"] =carol_df['Artist'].str.replace(r"\"","")
# Out:
# <ipython-input-11-4fa7528108a3>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   carol_df["Artist"] =carol_df['Artist'].str.replace(r"\"","")

# %%
carol_df.head(10)
# Out:
#                           Title  \
# 0  Christmas Eve/Sarajevo 12/24
# 1  Redneck 12 Days of Christmas
# 2                  Christmas Is
# 3                Christmas Time
# 4        Christmas Time Is Here
# 5                 Christmastime
# 6                Happy New Year
# 7                     Mistletoe
# 8    The Night Before Christmas
# 9                This Christmas
#
#                                               Artist  Year  \
# 0                                           Savatage  1996
# 1                                     Jeff Foxworthy  1995
# 2                  Jim Brickman featuring Mark Masri  2008
# 3                                      John Anderson  1994
# 4                                    Ray Parker, Jr.  1982
# 5                              The Smashing Pumpkins  1997
# 6                                               ABBA  1980
# 7                                      Justin Bieber  2011
# 8                                        Carly Simon  1992
# ...

# %%
# drop unwanted columns
carol_df = carol_df.drop(columns=['Additional information', 'Year'])
carol_df.head()
# Out:
#                           Title                             Artist
# 0  Christmas Eve/Sarajevo 12/24                           Savatage
# 1  Redneck 12 Days of Christmas                     Jeff Foxworthy
# 2                  Christmas Is  Jim Brickman featuring Mark Masri
# 3                Christmas Time                      John Anderson
# 4        Christmas Time Is Here                    Ray Parker, Jr.

# %%
# rename columns
carol_df = carol_df.rename(columns={'Title': 'Song', 'Artist': 'Performer'})
carol_df.head()
# Out:
#                            Song                          Performer
# 0  Christmas Eve/Sarajevo 12/24                           Savatage
# 1  Redneck 12 Days of Christmas                     Jeff Foxworthy
# 2                  Christmas Is  Jim Brickman featuring Mark Masri
# 3                Christmas Time                      John Anderson
# 4        Christmas Time Is Here                    Ray Parker, Jr.

# %%
# read in Top 100 Billboard csv
Top100_df = pd.read_csv('Top_100.csv')

# %%
Top100_df.head()
# Out:
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1965-0...  7/17/1965
# 1  http://www.billboard.com/charts/hot-100/1965-0...  7/24/1965
# 2  http://www.billboard.com/charts/hot-100/1965-0...  7/31/1965
# 3  http://www.billboard.com/charts/hot-100/1965-0...   8/7/1965
# 4  http://www.billboard.com/charts/hot-100/1965-0...  8/14/1965
#
#    Week Position                    Song   Performer  \
# 0             34  Don't Just Stand There  Patty Duke
# 1             22  Don't Just Stand There  Patty Duke
# 2             14  Don't Just Stand There  Patty Duke
# 3             10  Don't Just Stand There  Patty Duke
# 4              8  Don't Just Stand There  Patty Duke
#
#                              SongID  Instance  Previous Week Position  \
# 0  Don't Just Stand TherePatty Duke         1                    45.0
# 1  Don't Just Stand TherePatty Duke         1                    34.0
# ...

# %%
#drop unwanted columns
Top100_df.drop(columns= ['url'])
# Out:
#             WeekID  Week Position                      Song  \
# 0        7/17/1965             34    Don't Just Stand There
# 1        7/24/1965             22    Don't Just Stand There
# 2        7/31/1965             14    Don't Just Stand There
# 3         8/7/1965             10    Don't Just Stand There
# 4        8/14/1965              8    Don't Just Stand There
# ...            ...            ...                       ...
# 327890  10/20/2018             22            God Is A Woman
# 327891   5/21/1977             22   I Wanna Get Next To You
# 327892   5/23/1981             22          I Can't Stand It
# 327893   9/29/1973             22  Here I Am Come & Take Me
# 327894  11/28/2020             22                     Hawai
#
#                         Performer                                     SongID  \
# 0                      Patty Duke           Don't Just Stand TherePatty Duke
# 1                      Patty Duke           Don't Just Stand TherePatty Duke
# ...

# %%
# rename columns
Top100_df = Top100_df.rename(columns={'Week Position': 'week_position', 
                            'Previous Week Position': 'previous_week_position',
                          'Peak Position': 'peak_position',
                          'Weeks on Chart': 'weeks_on_chart'})
Top100_df.head()
# Out:
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1965-0...  7/17/1965
# 1  http://www.billboard.com/charts/hot-100/1965-0...  7/24/1965
# 2  http://www.billboard.com/charts/hot-100/1965-0...  7/31/1965
# 3  http://www.billboard.com/charts/hot-100/1965-0...   8/7/1965
# 4  http://www.billboard.com/charts/hot-100/1965-0...  8/14/1965
#
#    week_position                    Song   Performer  \
# 0             34  Don't Just Stand There  Patty Duke
# 1             22  Don't Just Stand There  Patty Duke
# 2             14  Don't Just Stand There  Patty Duke
# 3             10  Don't Just Stand There  Patty Duke
# 4              8  Don't Just Stand There  Patty Duke
#
#                              SongID  Instance  previous_week_position  \
# 0  Don't Just Stand TherePatty Duke         1                    45.0
# 1  Don't Just Stand TherePatty Duke         1                    34.0
# ...

# %%
# merge table of top_100 and carol merged on song and artist
merged_xmas = pd.read_csv('christmas_billboard_data.csv')
merged_xmas = merged_xmas.drop(columns = 'url')
merged_xmas
# Out:
#          weekid  week_position                                      song  \
# 0    12/13/1958             83                           RUN RUDOLPH RUN
# 1    12/20/1958             57                          JINGLE BELL ROCK
# 2    12/20/1958             73                           RUN RUDOLPH RUN
# 3    12/20/1958             86                           WHITE CHRISTMAS
# 4    12/27/1958             44                           GREEN CHRI$TMA$
# ..          ...            ...                                       ...
# 382    1/7/2017             16           ALL I WANT FOR CHRISTMAS IS YOU
# 383    1/7/2017             27         ROCKIN' AROUND THE CHRISTMAS TREE
# 384    1/7/2017             48  IT'S THE MOST WONDERFUL TIME OF THE YEAR
# 385   1/14/2017             35           ALL I WANT FOR CHRISTMAS IS YOU
# 386   1/14/2017             41                            LAST CHRISTMAS
#
#          performer                                             songid  \
# ...

# %%
# establish connection to database
# engine = create_engine(f"postgresql://{username}:{password}@localhost:5432/Top_Songs")
engine = create_engine(f"postgresql://postgres:postgres@localhost:5432/Top_Songs")
connection = engine.connect()

# %%
# create carol table in PostGres and upload data
import csv
from io import StringIO
def psql_insert_copy(table, conn, keys, data_iter):
    # gets a DBAPI connection that can provide a cursor
    dbapi_conn = conn.connection
    with dbapi_conn.cursor() as cur:
        s_buf = StringIO()
        writer = csv.writer(s_buf)
        writer.writerows(data_iter)
        s_buf.seek(0)

        columns = ', '.join('"{}"'.format(k) for k in keys)
        if table.schema:
            table_name = '{}.{}'.format(table.schema, table.name)
        else:
            table_name = table.name

        sql = 'COPY {} ({}) FROM STDIN WITH CSV'.format(
            table_name, columns)
        cur.copy_expert(sql=sql, file=s_buf)

carol_df.to_sql('carols', engine, method=psql_insert_copy)

# %%
# create top 100 table in PostGres and upload data
Top100_df.to_sql('top_100', engine, method=psql_insert_copy)

# %%
merged_xmas.to_sql('merged_xmas', engine, method=psql_insert_copy)
